# %% [markdown]
# ## Eval models

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import pandas as pd

# %%
def compute_eval_metrics(df, model_prompt):
    # 1. Map gold labels to 0/1
    df["gold_label"] = df["stop"].map({"stop": 1, "no_stop": 0})

    # 2. Filter out invalid predictions (-1)
    valid = df[df["predicted_label"] != -1]

    y_true = valid["gold_label"]
    y_pred = valid["predicted_label"]

    # 3. Compute metrics
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)    

    # --- Error breakdown ---
    errors = (y_true != y_pred)
    n_errors = errors.sum()
    fp = ((y_true == 0) & (y_pred == 1)).sum()
    fn = ((y_true == 1) & (y_pred == 0)).sum()
    fp_pct = fp / n_errors if n_errors > 0 else 0
    fn_pct = fn / n_errors if n_errors > 0 else 0

    # --- Class-wise F1 ---
    f1_pos = f1_score(y_true, y_pred, pos_label=1)
    f1_neg = f1_score(y_true, y_pred, pos_label=0)

    
    # Return as a DataFrame row
    return pd.DataFrame([{
        "model_prompt": model_prompt,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "accuracy": accuracy,
        "f1_stop(1)": f1_pos,
        "f1_no_stop(0)": f1_neg,
        "fp_pct_errors": fp_pct,
        "fn_pct_errors": fn_pct,
        "n_errors": n_errors,
        "n_samples": len(valid),
        "n_total": len(df)
    }])

# %%
# Load your annotated dataframe
#models_prompts = ["llama_basic", "llama_guide_context", "llama_guide", "llama_llama_context", "llama_llama", "qwen_guide_context", "qwen_guide", "qwen_llama_context", "qwen_llama", "mistral_guide", "mistral_llama"] 
models_prompts = ["qwen_guide_ouinon", "qwen_guide_few_ouinon", "qwen_guide_context_ouinon", "qwen_guide_few_context_ouinon", "qwen_guide_cot_context_ouinon", "mistral_guide_ouinon", "mistral_guide_ouinon_2", "mistral_guide_few_ouinon", "mistral_guide_few_ouinon_2", "mistral_guide_context_ouinon", "mistral_guide_few_context_ouinon", "mistral_guide_cot_context_ouinon", "llama_guide_ouinon", "llama_guide_few_ouinon", "llama_guide_context_ouinon", "llama_guide_cot_context_ouinon"]
results = []
for model_prompt in models_prompts:
    print("\n ======================= \n")
    print(f"COMPUTING EVALS METRICS FOR MODEL/PROMPT {model_prompt}")
    df = pd.read_csv('../data/eval_testset_' + model_prompt + '.csv', low_memory=False)
    res = compute_eval_metrics(df, model_prompt)
    results.append(res)

# Concatenate into one results table
results_df = pd.concat(results, ignore_index=True)
# Out:
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT qwen_guide_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT qwen_guide_few_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT qwen_guide_context_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT qwen_guide_few_context_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT qwen_guide_cot_context_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT mistral_guide_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT mistral_guide_ouinon_2
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT mistral_guide_few_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT mistral_guide_few_ouinon_2
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT mistral_guide_context_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT mistral_guide_few_context_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT mistral_guide_cot_context_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT llama_guide_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT llama_guide_few_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT llama_guide_context_ouinon
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT llama_guide_cot_context_ouinon

# %%
results_df
# Out:
#                         model_prompt  precision    recall  f1_score  accuracy  \
# 0                  qwen_guide_ouinon   0.672619  0.276961  0.392361  0.919178
# 1              qwen_guide_few_ouinon   0.541927  0.530637  0.536223  0.913500
# 2          qwen_guide_context_ouinon   0.569853  0.379902  0.455882  0.914560
# 3      qwen_guide_few_context_ouinon   0.345038  0.553922  0.425212  0.858810
# 4      qwen_guide_cot_context_ouinon   0.490806  0.425245  0.455680  0.904284
# 5               mistral_guide_ouinon   0.555858  0.267717  0.361382  0.912881
# 6             mistral_guide_ouinon_2   0.558583  0.269029  0.363153  0.913112
# 7           mistral_guide_few_ouinon   0.339009  0.626609  0.439980  0.836342
# 8         mistral_guide_few_ouinon_2   0.320081  0.653370  0.429670  0.820473
# 9       mistral_guide_context_ouinon   0.217913  0.382426  0.277628  0.798218
# 10  mistral_guide_few_context_ouinon   0.159975  0.648310  0.256626  0.613423
# 11  mistral_guide_cot_context_ouinon   0.229609  0.516332  0.317865  0.770850
# 12                llama_guide_ouinon   0.153031  0.566176  0.240939  0.663896
# 13            llama_guide_few_ouinon   0.127969  0.884804  0.223599  0.420949
# 14        llama_guide_context_ouinon   0.089785  0.936396  0.163858  0.227837
# 15    llama_guide_cot_context_ouinon   0.085239  0.653386  0.150805  0.469405
#
#     f1_stop(1)  f1_no_stop(0)  fp_pct_errors  fn_pct_errors  n_errors  \
# 0     0.392361       0.956710       0.157143       0.842857       700
# 1     0.536223       0.952302       0.488652       0.511348       749
# 2     0.455882       0.953640       0.316216       0.683784       740
# 3     0.425212       0.919521       0.702128       0.297872      1222
# 4     0.455680       0.947528       0.434258       0.565742       829
# 5     0.361382       0.953252       0.226075       0.773925       721
# 6     0.363153       0.953375       0.225313       0.774687       719
# 7     0.439980       0.904168       0.765919       0.234081      1115
# 8     0.429670       0.893470       0.800159       0.199841      1261
# 9     0.277628       0.882730       0.689677       0.310323      1608
# 10    0.256626       0.738794       0.906365       0.093635      3001
# 11    0.317865       0.862295       0.781746       0.218254      1764
# 12    0.240939       0.784163       0.878392       0.121608      2911
# 13    0.223599       0.538306       0.981252       0.018748      5014
# 14    0.163858       0.282721       0.993344       0.006656      5409
# 15    0.150805       0.614163       0.952897       0.047103      1847
#
#     n_samples  n_total
# 0        8661     8661
# 1        8659     8661
# 2        8661     8661
# 3        8655     8661
# 4        8661     8661
# 5        8276     8661
# 6        8275     8661
# 7        6813     8661
# 8        7024     8661
# 9        7969     8661
# 10       7763     8661
# 11       7698     8661
# 12       8661     8661
# 13       8659     8661
# 14       7005     8661
# 15       3481     8661
