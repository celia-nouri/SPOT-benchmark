# %% [markdown]
# ## Eval models

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import pandas as pd

# %%
def compute_eval_metrics(df, model_prompt):
    # 1. Map gold labels to 0/1
    df["gold_label"] = df["stop"].map({"stop": 1, "no_stop": 0})

    # 2. Filter out invalid predictions (-1)
    valid = df[df["predicted_label"] != -1]

    y_true = valid["gold_label"]
    y_pred = valid["predicted_label"]

    # 3. Compute metrics
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)    

    # --- Error breakdown ---
    errors = (y_true != y_pred)
    n_errors = errors.sum()
    fp = ((y_true == 0) & (y_pred == 1)).sum()
    fn = ((y_true == 1) & (y_pred == 0)).sum()
    fp_pct = fp / n_errors if n_errors > 0 else 0
    fn_pct = fn / n_errors if n_errors > 0 else 0

    # --- Class-wise F1 ---
    f1_pos = f1_score(y_true, y_pred, pos_label=1)
    f1_neg = f1_score(y_true, y_pred, pos_label=0)

    
    # Return as a DataFrame row
    return pd.DataFrame([{
        "model_prompt": model_prompt,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "accuracy": accuracy,
        "f1_stop(1)": f1_pos,
        "f1_no_stop(0)": f1_neg,
        "fp_pct_errors": fp_pct,
        "fn_pct_errors": fn_pct,
        "n_errors": n_errors,
        "n_samples": len(valid),
        "n_total": len(df)
    }])

# %%
# Load your annotated dataframe
models_prompts = ["llama_basic", "llama_guide_context", "llama_guide", "llama_llama_context", "llama_llama", "qwen_guide_context", "qwen_guide", "qwen_llama_context", "qwen_llama", "mistral_guide", "mistral_llama"]
results = []
for model_prompt in models_prompts:
    print("\n ======================= \n")
    print(f"COMPUTING EVALS METRICS FOR MODEL/PROMPT {model_prompt}")
    df = pd.read_csv('../data/eval_testset_' + model_prompt + '.csv', low_memory=False)
    res = compute_eval_metrics(df, model_prompt)
    results.append(res)

# Concatenate into one results table
results_df = pd.concat(results, ignore_index=True)
# Out:
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT llama_basic
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT llama_guide_context
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT llama_guide
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT llama_llama_context
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT llama_llama
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT qwen_guide_context
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT qwen_guide
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT qwen_llama_context
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT qwen_llama
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT mistral_guide
#
#  =======================
#
# COMPUTING EVALS METRICS FOR MODEL/PROMPT mistral_llama

# %%
results_df
# Out:
#            model_prompt  precision    recall  f1_score  accuracy  f1_stop(1)  \
# 0           llama_basic   0.000000  0.000000  0.000000  0.831776    0.000000
# 1   llama_guide_context   0.133873  0.634116  0.221073  0.550205    0.221073
# 2           llama_guide   0.156417  0.578492  0.246251  0.664205    0.246251
# 3   llama_llama_context   0.401515  0.065513  0.112646  0.903166    0.112646
# 4           llama_llama   0.164126  0.791667  0.271886  0.600508    0.271886
# 5    qwen_guide_context   0.697917  0.164216  0.265873  0.914560    0.265873
# 6            qwen_guide   0.496198  0.319853  0.388972  0.905323    0.388972
# 7    qwen_llama_context   0.338290  0.669118  0.449383  0.845514    0.449383
# 8            qwen_llama   0.214082  0.827206  0.340136  0.697610    0.340136
# 9         mistral_guide   0.297158  0.422794  0.349014  0.851317    0.349014
# 10        mistral_llama   0.259798  0.568627  0.356649  0.806720    0.356649
#
#     f1_no_stop(0)  fp_pct_errors  fn_pct_errors  n_errors  n_samples  n_total
# 0        0.908163       0.013889       0.986111        72        428     8661
# 1        0.683810       0.918119       0.081881      3615       8037     8661
# 2        0.783986       0.880977       0.119023      2865       8532     8661
# 3        0.948789       0.094611       0.905389       835       8623     8661
# 4        0.724741       0.950867       0.049133      3460       8661     8661
# 5        0.954640       0.078378       0.921622       740       8661     8661
# 6        0.948686       0.323171       0.676829       820       8661     8661
# 7        0.910153       0.798206       0.201794      1338       8661     8661
# 8        0.803864       0.946163       0.053837      2619       8661     8661
# 9        0.916074       0.634033       0.365967      1287       8656     8661
# 10       0.886277       0.789725       0.210275      1674       8661     8661
